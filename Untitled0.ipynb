# %%
! pwd
# Out:
# /content

# %%
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks/misad')

# %%
! pwd
# Out:
# /content/drive/My Drive/Colab Notebooks/misad

# %%
! git config --global user.email "yuss1105@gmail.com"
! git config --global user.name "YUYSS"

# %%
! git init
# Out:
# Reinitialized existing Git repository in /content/drive/My Drive/Colab Notebooks/misad/.git/

# %%
! git add -A
! git commit -m "first commit"
# Out:
# [master (root-commit) fe8cd77] first commit
#  1 file changed, 1 insertion(+)
#  create mode 100644 Untitled0.ipynb

# %%
! git remote add origin https://yuss1105@gmail.com:13208023432yuss@github.com/YUYSS/misad.git
! git branch -M main
! git push -u origin main
# Out:
# fatal: remote origin already exists.
# fatal: could not read Username for 'https://github.com': No such device or address
